# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusuf5001/DA-with-Python/blob/main/SELF_STUDY_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr_1 = np.array([4,9,16,25,36])
arr_2 = np.array([2,3,4,5,6])
np.sqrt(arr_1)-np.max(arr_2)
# Out:
# array([-4., -3., -2., -1.,  0.])

# %%
arr = np.arange(1,6)
arr.shape
# Out:
# (5,)

# %%
def summ(a):
  sum=0
  for i in a:
    sum += int(i)
  return sum
summ(str(input("Pls enter a number:")))
# Out:
# Pls enter a number:258
# 15

# %%
def summ(a):
  sum=0
  for i in a:
    sum += i
  return sum
summ((input("Pls enter a number:").split()))
# Out:
# Pls enter a number:22
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c53c0403e691> in <module>()
#       4     sum += i
#       5   return sum
# ----> 6 summ((input("Pls enter a number:").split()))
#
# <ipython-input-11-c53c0403e691> in summ(a)
#       2   sum=0
#       3   for i in a:
# ----> 4     sum += i
#       5   return sum
#       6 summ((input("Pls enter a number:").split()))
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
cd /content/sample_data/
# Out:
# /content/sample_data

# %%
df =pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.drop([	"SibSp", "Parch",	"Ticket",	"Cabin"], axis=1).head()
# Out:
#    PassengerId  Survived  Pclass  ...   Age     Fare  Embarked
# 0            1         0       3  ...  22.0   7.2500         S
# 1            2         1       1  ...  38.0  71.2833         C
# 2            3         1       3  ...  26.0   7.9250         S
# 3            4         1       1  ...  35.0  53.1000         S
# 4            5         0       3  ...  35.0   8.0500         S
#
# [5 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pd.value_counts(df["Survived"]).plot.bar()

# %%
df["Survived"].mean()
# Out:
# 0.3838383838383838

# %%
df.groupby(["Sex","Pclass"]).mean()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch        Fare
# Sex    Pclass
# female 1        469.212766  0.968085  34.611765  0.553191  0.457447  106.125798
#        2        443.105263  0.921053  28.722973  0.486842  0.605263   21.970121
#        3        399.729167  0.500000  21.750000  0.895833  0.798611   16.118810
# male   1        455.729508  0.368852  41.281386  0.311475  0.278689   67.226127
#        2        447.962963  0.157407  30.740707  0.342593  0.222222   19.741782
#        3        455.515850  0.135447  26.507589  0.498559  0.224784   12.661633

# %%
df[df["Age"]<18].groupby(["Sex", "Pclass"]).mean()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch        Fare
# Sex    Pclass
# female 1        525.375000  0.875000  14.125000  0.500000  0.875000  104.083337
#        2        369.250000  1.000000   8.333333  0.583333  1.083333   26.241667
#        3        374.942857  0.542857   8.428571  1.571429  1.057143   18.727977
# male   1        526.500000  1.000000   8.230000  0.500000  2.000000  116.072900
#        2        527.818182  0.818182   4.757273  0.727273  1.000000   25.659473
#        3        437.953488  0.232558   9.963256  2.069767  1.000000   22.752523

# %%
series = pd.Series(("Nick", "P", 30, "nick@email.com", 175.6))
series
# Out:
# 0              Nick
# 1                 P
# 2                30
# 3    nick@email.com
# 4             175.6
# dtype: object

# %%
dataframe1 = pd.DataFrame([("Nick", "P", 30, "nick@email.com", 175.6),
                           ("Peak", "N", 25, "peak@email.com", 156.7)],
                          columns=["First Name","Last Initial", "Age", "Email", "Height" ])
dataframe1
# Out:
#   First Name Last Initial  Age           Email  Height
# 0       Nick            P   30  nick@email.com   175.6
# 1       Peak            N   25  peak@email.com   156.7

# %%
dataframe1 = pd.DataFrame({"First Name":["Nick","Peak"],
                          "Last Inital":["P", "D"],
                           "Age":[30,25],
                           "Email":["nick@gmail.com", "peak@email.com"],
                           "Height":[175.6, 156.7]
                           })
dataframe1
# Out:
#   First Name Last Inital  Age           Email  Height
# 0       Nick           P   30  nick@gmail.com   175.6
# 1       Peak           D   25  peak@email.com   156.7

# %%
df=pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv")
df
# Out:
#     Rank  Major_code  ... ShareWomen  Median
# 0      1        2419  ...   0.120564  110000
# 1      2        2416  ...   0.101852   75000
# 2      3        2415  ...   0.153037   73000
# 3      4        2417  ...   0.107313   70000
# 4      5        2418  ...   0.144967   65000
# ..   ...         ...  ...        ...     ...
# 71    72        3604  ...   0.576360   33000
# 72    73        6109  ...   0.721866   33000
# 73    74        6100  ...   0.774577   32400
# 74    75        6102  ...   0.967998   28000
# 75    76        3609  ...   0.637293   26000
#
# [76 rows x 9 columns]

# %%
df.shape
# Out:
# (76, 9)

# %%
df.head()
# Out:
#    Rank  Major_code  ... ShareWomen  Median
# 0     1        2419  ...   0.120564  110000
# 1     2        2416  ...   0.101852   75000
# 2     3        2415  ...   0.153037   73000
# 3     4        2417  ...   0.107313   70000
# 4     5        2418  ...   0.144967   65000
#
# [5 rows x 9 columns]

# %%
df.head(10)
# Out:
#    Rank  Major_code  ... ShareWomen  Median
# 0     1        2419  ...   0.120564  110000
# 1     2        2416  ...   0.101852   75000
# 2     3        2415  ...   0.153037   73000
# 3     4        2417  ...   0.107313   70000
# 4     5        2418  ...   0.144967   65000
# 5     6        2405  ...   0.341631   65000
# 6     7        5001  ...   0.535714   62000
# 7     8        2414  ...   0.119559   60000
# 8     9        2401  ...   0.139793   60000
# 9    10        2408  ...   0.196450   60000
#
# [10 rows x 9 columns]

# %%
df.tail()
# Out:
#     Rank  Major_code  ... ShareWomen Median
# 71    72        3604  ...   0.576360  33000
# 72    73        6109  ...   0.721866  33000
# 73    74        6100  ...   0.774577  32400
# 74    75        6102  ...   0.967998  28000
# 75    76        3609  ...   0.637293  26000
#
# [5 rows x 9 columns]

# %%
df.sample()
# Out:
#     Rank  Major_code  ... ShareWomen Median
# 62    63        5098  ...   0.564639  35000
#
# [1 rows x 9 columns]

# %%
df.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-57e850d2cc5f> in <module>()
# ----> 1 df.values()
#
# TypeError: 'numpy.ndarray' object is not callable
