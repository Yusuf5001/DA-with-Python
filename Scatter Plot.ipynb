# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
insurance_filepath = "insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
plt.show()

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
plt.show()

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
plt.show()

# %%
#Plot data and regression model fits across a FacetGrid.
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)
plt.show()

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
plt.show()
# Out:
# C:\Users\44778\anaconda3\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\44778\anaconda3\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Path of the file to read
candy_filepath = "candy.csv"

# Fill in the line below to read the file into a variable candy_data
candy_data = pd.read_csv("candy.csv", index_col="id")

# %%
candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
candy_data.winpercent.head()
# Out:
# id
# 0    66.971725
# 1    67.602936
# 2    52.341465
# 3    50.347546
# 4    56.914547
# Name: winpercent, dtype: float64

# %%
candy_data[candy_data.competitorname=="3 Musketeers"]
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 1    3 Musketeers       Yes     No      No             No    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 1                No   No  Yes       No         0.604         0.511   67.602936

# %%
candy_data[candy_data.competitorname=="Almond Joy"]
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 3      Almond Joy       Yes     No      No            Yes     No
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 3                No   No  Yes       No         0.465         0.767   50.347546

# %%
candy_data[candy_data.competitorname=="Air Heads"]
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 2       Air Heads        No    Yes      No             No     No
#
#    crispedricewafer hard bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 2                No   No  No       No         0.906         0.511   52.341465

# %%
candy_data[candy_data.competitorname=="Baby Ruth"]
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
plt.show()

# %%
#Plot data and regression model fits across a FacetGrid.
sns.lmplot(x='sugarpercent', y='winpercent', data=candy_data)
plt.show()

# %%
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'], hue=candy_data["chocolate"])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.lmplot(x="sugarpercent", y="winpercent", hue="chocolate", data=candy_data)

# %%
candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
insurance_filepath = "i.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %%
import numpy as np

# %%
iris_data = pd.read_csv("iris.csv")

# %%
iris_data.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
sns.histplot(iris_data['Petal Length (cm)'])
plt.show()

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# Out:
# C:\Users\44778\AppData\Local\Temp\ipykernel_17296\4247869334.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %%
# Histograms for each species
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')

# Add title
plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')

# %%
# KDE plots for each species
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# C:\Users\44778\AppData\Local\Temp\ipykernel_17296\1557107132.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')

# %%
cancer_filepath = "cancer.csv"

# Fill in the line below to read the file into a variable cancer_data
cancer_data = pd.read_csv("cancer.csv",index_col="Id")

# %%
cancer_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
cancer_data["Perimeter (mean)"].sort_values()
# Out:
# Id
# 862722        43.79
# 92751         47.92
# 921092        47.98
# 921362        48.34
# 85713702      51.71
#               ...
# 8611555      171.50
# 899987       174.20
# 873592       182.10
# 911296202    186.90
# 8810703      188.50
# Name: Perimeter (mean), Length: 569, dtype: float64

# %%
cancer_data.loc[8510824]["Radius (mean)"]
# Out:
# 9.504

# %%
sns.histplot(data=cancer_data, x='Area (mean)', hue='Diagnosis')
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Count'>

# %%
sns.kdeplot(data=cancer_data, x='Radius (worst)', hue='Diagnosis', shade=True)
# Out:
# C:\Users\44778\AppData\Local\Temp\ipykernel_17296\3132394545.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=cancer_data, x='Radius (worst)', hue='Diagnosis', shade=True)
# <AxesSubplot:xlabel='Radius (worst)', ylabel='Density'>
