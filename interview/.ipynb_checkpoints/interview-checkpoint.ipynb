# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid") 
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 150 
pd.options.display.max_columns = 100

# %%
curreny = pd.read_csv("currency_rates_082020_EUR.csv")
curreny.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020 1.000
# 1      EUR  8/2/2020 1.000
# 2      EUR  8/3/2020 1.000
# 3      EUR  8/4/2020 1.000
# 4      EUR  8/5/2020 1.000

# %%
curreny.sample(10)
# Out:
#     currency       date    rate
# 88       SEK   8/9/2020  10.312
# 177      MYR   8/8/2020   4.951
# 68       HKD   8/9/2020   9.132
# 72       CHF   8/3/2020   1.079
# 62       HKD   8/3/2020   9.116
# 87       SEK   8/8/2020  10.314
# 63       HKD   8/4/2020   9.157
# 149      JPY  8/10/2020 124.410
# 179      MYR  8/10/2020   4.928
# 36       AUD   8/7/2020   1.646

# %% [markdown]
# # 1. How many rows in the sales dataset?(Just write numbers) *

# %%
sales.shape
# Out:
# (237671, 10)

# %% [markdown]
# # 2. How many columns in the sales dataset?(Just write numbers) *

# %%
sales.shape
# Out:
# (237671, 10)

# %% [markdown]
# # 3. What is the total number of sellers?(Just write numbers) *

# %%
sales.seller_id.value_counts()
# Out:
# pzsiehl0    703
# wd3rgi3q    525
# j21w87xy    500
# dbm0o9qu    436
# hbtm3tdy    316
#            ...
# mc71pjkf      1
# yamuk1cp      1
# 4el4bfqh      1
# li55skub      1
# 8jpvi76p      1
# Name: seller_id, Length: 114227, dtype: int64

# %% [markdown]
# # 4. What is the total value of sales in EUR?(Just write numbers) *

# %%
sales.loc[sales["currency"]=="EUR"]["buyer_id"].count()
# Out:
# 5934

# %% [markdown]
# # 5. Which brand has the highest number of purchases?(Write down brand as in dataset, answer is case sensitive) *

# %%
sales.groupby("brand")["buyer_id"].count().sort_values(ascending=False)
# Out:
# brand
# Nike                  9575
# Brandy Melville       5065
# Topshop               4561
# PrettyLittle Thing    4136
# Adidas                3905
#                       ...
# Araks                    1
# Elegant Moments          1
# Top Stitch               1
# ADYN                     1
# Filson                   1
# Name: buyer_id, Length: 1134, dtype: int64

# %%
sales = pd.read_csv("sales_082020.csv")
sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP 19.110  2020-08-03
# 1         Outerwear  Adidas Originals      GBP 15.920  2020-08-09
# 2       Tops - Mens               NaN      GBP  6.370  2020-08-07
# 3       Tops - Mens          Berghaus      GBP 25.270  2020-08-09
# 4  Bottoms - Womens               NaN      GBP  8.900  2020-08-09

# %%
df = pd.merge(sales, curreny, how="inner", on=["date"])
df.head()
# Out:
# Empty DataFrame
# Columns: [buyer_id, buyer_country, seller_id, seller_country, product_code, category, brand, currency_x, price, date, currency_y, rate]
# Index: []

# %%
df.rate.isnull().count()
# Out:
# 237891

# %% [markdown]
# # 6. How many items in the “Jewelry” category have no brand?(Just write numbers)

# %%
sales[sales["category"]=="Jewellery"].count()
# Out:
# buyer_id          14923
# buyer_country     14923
# seller_id         14923
# seller_country    14923
# product_code      14923
# category          14923
# brand              1398
# currency          14923
# price             14923
# date              14923
# dtype: int64

# %%
sales.isnull().sum()
# Out:
# buyer_id               0
# buyer_country          0
# seller_id              0
# seller_country         0
# product_code           0
# category              16
# brand             118341
# currency               0
# price                  0
# date                   0
# dtype: int64

# %%
sales.groupby("seller_id").count()
# Out:
#            buyer_id  buyer_country  seller_country  product_code  category  \
# seller_id
# 00026zrn          1              1               1             1         1
# 000aaqnz          1              1               1             1         1
# 0011guej          1              1               1             1         1
# 00185ns7          1              1               1             1         1
# 001r1gvf          1              1               1             1         1
# ...             ...            ...             ...           ...       ...
# zzy962vt          2              2               2             2         2
# zzy993vl          1              1               1             1         1
# zzythjtn          3              3               3             3         3
# zzzqa0ik          1              1               1             1         1
# zzzzlrla          1              1               1             1         1
#
#            brand  currency  price  date
# seller_id
# ...

# %%
df.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020 1.000
# 1      EUR  8/2/2020 1.000
# 2      EUR  8/3/2020 1.000
# 3      EUR  8/4/2020 1.000
# 4      EUR  8/5/2020 1.000

# %%
df.shape
# Out:
# (220, 3)

# %%
df2.buyer_id.value_counts()
# Out:
# x0aflhz7fd    218
# ufuficiwue    185
# vtni4i6eh9    145
# i7yojjk30i    115
# 1be840z6cb     77
#              ...
# dcn2a9wg5w      1
# xlih3rurka      1
# ovrl72hqlk      1
# kx76j384f9      1
# 9osyhmbwhf      1
# Name: buyer_id, Length: 139700, dtype: int64

# %%
sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP 19.110  2020-08-03
# 1         Outerwear  Adidas Originals      GBP 15.920  2020-08-09
# 2       Tops - Mens               NaN      GBP  6.370  2020-08-07
# 3       Tops - Mens          Berghaus      GBP 25.270  2020-08-09
# 4  Bottoms - Womens               NaN      GBP  8.900  2020-08-09

# %% [markdown]
# # 7. How many brands have number of transactions between 35 and 55 (inclusive)?(Just write numbers)

# %%
sales[(sales["price"]>=35) & (sales["price"]<=55)].count()
# Out:
# buyer_id          25746
# buyer_country     25746
# seller_id         25746
# seller_country    25746
# product_code      25746
# category          25743
# brand             13980
# currency          25746
# price             25746
# date              25746
# dtype: int64

# %%
sales[(sales["price"]>=35) & (sales["price"]<=55)]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 14      1g3678i0mb            GB  9p2ansc9             GB  xjm3k96m1t08
# 87      mebpkmv8wu            GB  cayk63ux             GB  gcqxtjyj5vmb
# 88      dhlgt7vxuz            GB  cayk63ux             GB  5px9ldgnrgrx
# 100     kfodrz4mon            GB  5a5i67ye             GB  zkk1mev638ee
# 120     4ifsz8t7ro            GB  x39v38nj             GB  lo1b8mao9pve
# ...            ...           ...       ...            ...           ...
# 237624  o0pn7jisi0            GB  u14l0n35             GB  5ej4zmigo5k8
# 237640  grik173oqv            AU  ne06kqik             AU  0di422kgfkd7
# 237641  6vkxwrdl8f            US  kcwtccl3             GB  jsrq5royln2r
# 237647  q3p142k8mv            GB  kkyg24rq             GB  hb5j3fokgapk
# 237648  05ll13z5pg            US  ahrll085             US  ixq14b4r77n6
#
#                 category          brand currency  price        date
# ...

# %% [markdown]
# # 8. How many pairs of shoes were purchased by Australian (AU) buyers?(Just write numbers)

# %%
sales[sales["buyer_country"]=="AU"].count()
# Out:
# buyer_id          7868
# buyer_country     7868
# seller_id         7868
# seller_country    7868
# product_code      7868
# category          7868
# brand              305
# currency          7868
# price             7868
# date              7868
# dtype: int64

# %%
#sales.groupby("category")[sales.loc["buyer_country"]=="AU"].value_counts()

sales.loc[(sales["buyer_country"]=="AU") & (sales["category"]=="Shoes")]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 139     ex9bpqq8w6            AU  j3pkou10             US  2tzszjhssh03
# 539     uru4etz7e5            AU  1i84ez1k             AU  zzu9hpjsjx6o
# 5639    9fn32ae6a9            AU  arloo1le             GB  a2gdza98bia7
# 7117    40jm2mgsri            AU  toud3ymd             AU  so29y8tl6rvs
# 7118    ncxx01xn4j            AU  toud3ymd             AU  utn7clcp7j3n
# ...            ...           ...       ...            ...           ...
# 236930  azmnowovd7            AU  xgse9ed3             AU  1xzq0f7a31bi
# 237075  i0loqi83nv            AU  f8ts15sr             AU  zvrlgzyse7j6
# 237495  86aw49gm0m            AU  seb5z7bo             AU  xeebt9i4gyo3
# 237497  pcd2mdsr3n            AU  agzes91a             AU  bvqweclvm8tx
# 237575  0s9ms8inq0            AU  zkon4br2             AU  srw1zpebx9zo
#
#        category     brand currency   price        date
# ...

# %% [markdown]
# # 9.Which brand has the highest average transaction value? (Just write brand name)

# %%
sales.groupby("brand")["price"].mean().sort_values(ascending=False)
# Out:
# brand
# Goyard                   339.363
# Loewe                    302.043
# Loeffler Randall         244.840
# Craig Green              239.940
# Walter Van Beirendonck   216.180
#                            ...
# MUA                        4.687
# Max Factor                 3.912
# Bronica                    3.786
# 36572                      1.120
# 360 Cashmere               1.120
# Name: price, Length: 1134, dtype: float64

# %%
sales[sales["brand"]=="Goyard"]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 207779  4apb7hkkrg            US  51hvkkqe             US  v1s2e0mstiqf
# 211959  4apb7hkkrg            US  u732wbdx             GB  a32h5lapka5y
# 231433  juffom4kqw            GB  lnkbhwtk             GB  zh0w6n6v6gk4
#
#            category   brand currency   price        date
# 207779  Accessories  Goyard      USD 417.430  2020-08-05
# 211959  Accessories  Goyard      GBP 552.060  2020-08-07
# 231433  Accessories  Goyard      GBP  48.600  2020-08-05

# %%
sales[sales["brand"]=="Loewe"]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 126759  2po9tirfd6            GB  n3e2i7o1             GB  ma4bktd0oe4q
# 210078  ccx9zaspyl           RoW  t7kqrsdv             GB  abnlea5d6vi6
# 212131  45q1119tw6            US  kdyftzk6             GB  smlxt813a1jg
#
#            category  brand currency   price        date
# 126759  Accessories  Loewe      GBP  73.230  2020-08-03
# 210078  Accessories  Loewe      GBP 706.550  2020-08-08
# 212131  Accessories  Loewe      GBP 126.350  2020-08-08

# %%
sales[sales["brand"]=="Nike"]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 7       bob9rlo4lb            GB  9p2ansc9             GB  jfncu4dmfnoc
# 8       bob9rlo4lb            GB  9p2ansc9             GB  ssmpsnfvopu9
# 17      rfzhjmd2by            GB  9p2ansc9             GB  vpvmahrcrm87
# 268     rbtqqboznp            US  h84epmg0             US  h98i9z6he4y4
# 283     jvkmmfy94d            GB  3u54hwb8             GB  yl2wncie74ia
# ...            ...           ...       ...            ...           ...
# 237552  jqi626lpuk            GB  x02pfzr3             GB  yjg3tq14zt1l
# 237575  0s9ms8inq0            AU  zkon4br2             AU  srw1zpebx9zo
# 237594  k1ohbg5unn            GB  c5gvd10l             GB  lc46fov5scgx
# 237622  1d5mdkqvas            US  rwzkhbqt             US  i2h9j2wyucew
# 237630  2snrpc5xah            GB  rqxp83c6             GB  uyxizoz8j95r
#
#                 category brand currency   price        date
# ...

# %%
sales.loc[sales["brand"]=="Nike", "price"].mean()
# Out:
# 39.0140187989556

# %%
sales.loc[sales["brand"]=="Loewe", "price"].mean()
# Out:
# 302.04333333333335

# %% [markdown]
# # 10. What is the total value of items purchased by GB buyers from GB sellers? (Just write numbers)

# %%
sales.loc[(sales["buyer_country"]=="GB") & (sales["seller_country"]=="GB")].count()
# Out:
# buyer_id          133876
# buyer_country     133876
# seller_id         133876
# seller_country    133876
# product_code      133876
# category          133868
# brand              77768
# currency          133876
# price             133876
# date              133876
# dtype: int64

# %% [markdown]
# # 11. What percentage of US sellers' transactions were purchased by US buyers? (Just write percentage)

# %%
buyer_us = sales.loc[sales["seller_country"]=="US"]
buyer_us["buyer_id"].count()
# Out:
# 82111

# %%
buyer_seller_us = sales.loc[(sales["seller_country"]=="US") & (sales["buyer_country"]=="US")]
buyer_seller_us
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 23      94lh9gu3bu            US  dhsa2q6o             US  1m846u2l2dyl
# 24      fmdcxftbp1            US  dhsa2q6o             US  9xo46id3ggkm
# 79      nk167akpfw            US  zhu1ajrz             US  431v9gn7ouiw
# 80      nk167akpfw            US  zhu1ajrz             US  36o939nzswpa
# 81      nk167akpfw            US  zhu1ajrz             US  8mli531pzaba
# ...            ...           ...       ...            ...           ...
# 237660  f9jbvr90xu            US  quu0ky19             US  50vyfd46inih
# 237662  say6ah2869            US  2jwn7shh             US  dfo3ztaga4de
# 237663  jji9og2wj0            US  w8g31gsr             US  gjwpt7hxl03u
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#              category             brand currency   price        date
# ...

# %%
buyer_seller_us["buyer_id"].count()
# Out:
# 80658

# %%
percent = (buyer_seller_us["buyer_id"].count() / buyer_us["buyer_id"].count())*100
percent
# Out:
# 98.23044415486353

# %%
sales.isnull().sum()
# Out:
# buyer_id               0
# buyer_country          0
# seller_id              0
# seller_country         0
# product_code           0
# category              16
# brand             118341
# currency               0
# price                  0
# date                   0
# dtype: int64

# %%
sales.loc[(sales["seller_country"]!="US") & (sales["buyer_country"]=="US")]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 357     469ev2x32r            US  li8btpfy             GB  kbg3gmcnb8rl
# 370     53gg3umgf3            US  li8btpfy             GB  0dej9ls042j8
# 695     ccmq9ynv8j            US  y2c4v2ov             GB  kdkahxoxpd9v
# 831     msnx3rm5nt            US  7gnv6cwu             GB  5ucm5j19fzv5
# 871     g42n99u1sc            US  60v168cm             GB  7lwgjwmpt7wn
# ...            ...           ...       ...            ...           ...
# 237434  969nzz6w3p            US  qmmitetm             AU  rz20v0hjv45a
# 237522  wdfboy22ht            US  fr0p43mi             GB  geqiwniz29df
# 237563  c6x3hfpbr5            US  da65rf64             AU  nmkfsyuqgaul
# 237610  haoeoj9vz6            US  afs1scsy             CA  hjcckmws5sbf
# 237641  6vkxwrdl8f            US  kcwtccl3             GB  jsrq5royln2r
#
#                 category   brand currency  price        date
# ...
