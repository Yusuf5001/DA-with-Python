# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\44778\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\44778\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel('RESTAURANT INVENTORY LOG.xlsx', 
                   sheet_name='Inventory Worksheets')

df
# Out:
# C:\Users\44778\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#      Unnamed: 0   Inventory Item Active  Location  Vendor  \
# 0           NaN   10oz Soup bowl      y  Dish Rack   Edon
# 1           NaN      Abita Turbo      Y   Tiki Bar  Faust
# 2           NaN  AE Blood Orange      Y   Tiki Bar  Faust
# 3           NaN  AE Hopped Cider      Y   Tiki Bar  Faust
# 4           NaN      AE Original      n   Tiki Bar  Faust
# ..          ...              ...    ...        ...    ...
# 815         NaN              NaN    NaN        NaN    NaN
# 816         NaN              NaN    NaN        NaN    NaN
# 817         NaN              NaN    NaN        NaN    NaN
# 818         NaN              NaN    NaN        NaN    NaN
# 819         NaN              NaN    NaN        NaN    NaN
#
#                   Sub Cat       Cat Order Unit Pack/Size  \
# 0         50203 · KITCHEN  SUPPLIES       Each      Each
# 1    50010 · BOTTLED BEER       LBW       Case   24/12oz
# 2    50010 · BOTTLED BEER       LBW       each   24/12oz
# 3    50010 · BOTTLED BEER       LBW       Case   24/12oz
# 4    50010 · BOTTLED BEER       LBW       Case   24/12oz
# ..                    ...       ...        ...       ...
# 815                   NaN       NaN        NaN       NaN
# 816                   NaN       NaN        NaN       NaN
# 817                   NaN       NaN        NaN       NaN
# 818                   NaN       NaN        NaN       NaN
# 819                   NaN       NaN        NaN       NaN
#
#      current CS/PUR Unit Price  IUM to PUM Ratio  current IUM Price  \
# 0                        26.30              12.0           2.191667
# 1                        29.85              24.0           1.243750
# 2                        30.55              24.0           1.272917
# 3                        29.55              24.0           1.231250
# 4                        29.95              24.0           1.247917
# ..                         ...               ...                ...
# 815                        NaN               NaN                NaN
# 816                        NaN               NaN                NaN
# 817                        NaN               NaN                NaN
# 818                        NaN               NaN                NaN
# 819                        NaN               NaN                NaN
#
#      Week 11 Count WK COUNT BY  WK INV Value  Comments Location Position
# 0              NaN        Each           0.0       NaN               NaN
# 1              NaN         Btl           0.0       NaN               NaN
# 2              NaN         Btl           0.0       NaN               NaN
# 3              NaN         Btl           0.0       NaN               NaN
# 4              NaN        Each           0.0       NaN               NaN
# ..             ...         ...           ...       ...               ...
# 815            NaN         NaN           NaN       NaN               NaN
# 816            NaN         NaN           NaN       NaN               NaN
# 817            NaN         NaN           NaN       NaN               NaN
# 818            NaN         NaN           NaN       NaN               NaN
# 819            NaN         NaN           NaN       NaN               NaN
#
# [820 rows x 17 columns]

# %%
df = pd.read_excel('RESTAURANT INVENTORY LOG.xlsx', 
                   sheet_name='Inventory Worksheets',
                   usecols="B:Q", 
                   nrows=797)
df
# Out:
# C:\Users\44778\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                 Inventory Item Active       Location     Vendor  \
# 0               10oz Soup bowl      y       Dish Rack      Edon
# 1                  Abita Turbo      Y        Tiki Bar     Faust
# 2              AE Blood Orange      Y        Tiki Bar     Faust
# 3              AE Hopped Cider      Y        Tiki Bar     Faust
# 4                  AE Original      n        Tiki Bar     Faust
# ..                         ...    ...             ...       ...
# 792    Worchestershire, Gallon      y     Dry Storage     Sysco
# 793                      Yeast      y    Bakers Table     Sysco
# 794                     Yogurt      Y  Walk in Cooler     Sysco
# 795                Ziegen Bock      y     Beer Cooler  DelPappa
# 796  Zing Zang Bloody Mary Mix      y        Tiki Bar     Specs
#
#                   Sub Cat       Cat Order Unit Pack/Size  \
# 0         50203 · KITCHEN  SUPPLIES       Each      Each
# 1    50010 · BOTTLED BEER       LBW       Case   24/12oz
# 2    50010 · BOTTLED BEER       LBW       each   24/12oz
# 3    50010 · BOTTLED BEER       LBW       Case   24/12oz
# 4    50010 · BOTTLED BEER       LBW       Case   24/12oz
# ..                    ...       ...        ...       ...
# 792       50001 · GROCERY      FOOD       Each    1/1gal
# 793       50001 · GROCERY      FOOD       Case    20/1lb
# 794         50007 · DAIRY      FOOD       Case    6/32oz
# 795  50010 · BOTTLED BEER       LBW       Case   24/12oz
# 796      50008 · BEVERAGE      FOOD       Each      Each
#
#      current CS/PUR Unit Price  IUM to PUM Ratio  current IUM Price  \
# 0                        26.30              12.0           2.191667
# 1                        29.85              24.0           1.243750
# 2                        30.55              24.0           1.272917
# 3                        29.55              24.0           1.231250
# 4                        29.95              24.0           1.247917
# ..                         ...               ...                ...
# 792                       7.22               1.0           7.220000
# 793                      51.93              20.0           2.596500
# 794                      16.97               6.0           2.828333
# 795                      28.25              24.0           1.177083
# 796                       4.39               1.0           4.390000
#
#      Week 11 Count WK COUNT BY  WK INV Value  Comments Location Position
# 0              NaN        Each             0       NaN               NaN
# 1              NaN         Btl             0       NaN               NaN
# 2              NaN         Btl             0       NaN               NaN
# 3              NaN         Btl             0       NaN               NaN
# 4              NaN        Each             0       NaN               NaN
# ..             ...         ...           ...       ...               ...
# 792            NaN      Gallon             0       NaN                78
# 793            NaN          Lb             0       NaN             BT131
# 794            NaN       Quart             0       NaN             WC370
# 795            NaN         Btl             0       NaN               NaN
# 796            NaN        Each             0       NaN               NaN
#
# [797 rows x 16 columns]

# %%
rows_to_skip = list(range(0,5))
rows_to_skip.append(6)

# %%
df = pd.read_excel('RESTAURANT INVENTORY LOG.xlsx', 
                   sheet_name='Subcategory Inventory Value',
