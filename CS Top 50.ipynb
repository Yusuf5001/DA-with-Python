# %%
import pandas as pd

# %%
df = pd.read_csv("Untitled spreadsheet - Sheet1.csv", )

# %%
df
# Out:
#         Player  Teams  Maps  Rounds  K-D Diff   K/D  Rating2.0
# 0        ZywOo    NaN   140    3869       881  1.39       1.29
# 1        sh1ro    NaN   128    3540       801  1.41       1.23
# 2         NiKo    NaN   117    3106       368  1.19       1.20
# 3       m0NESY    NaN   117    3106       543  1.30       1.20
# 4       blameF    NaN   123    3432       432  1.21       1.19
# 5       s1mple    NaN   121    3311       505  1.25       1.19
# 6        Ax1Le    NaN   117    3221       327  1.16       1.16
# 7         ropz    NaN   144    3871       482  1.20       1.14
# 8        stavn    NaN   143    3824       253  1.10       1.13
# 9     SunPayus    NaN   109    2996       364  1.21       1.13
# 10       broky    NaN   144    3871       470  1.20       1.12
# 11       Spinx    NaN   140    3869       329  1.13       1.11
# 12     Twistzz    NaN   144    3871       227  1.09       1.10
# 13         NAF    NaN   129    3484       233  1.11       1.09
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
df.index+=1

# %%
df
# Out:
#         Player  Teams  Maps  Rounds  K-D Diff   K/D  Rating2.0
# 1        ZywOo    NaN   140    3869       881  1.39       1.29
# 2        sh1ro    NaN   128    3540       801  1.41       1.23
# 3         NiKo    NaN   117    3106       368  1.19       1.20
# 4       m0NESY    NaN   117    3106       543  1.30       1.20
# 5       blameF    NaN   123    3432       432  1.21       1.19
# 6       s1mple    NaN   121    3311       505  1.25       1.19
# 7        Ax1Le    NaN   117    3221       327  1.16       1.16
# 8         ropz    NaN   144    3871       482  1.20       1.14
# 9        stavn    NaN   143    3824       253  1.10       1.13
# 10    SunPayus    NaN   109    2996       364  1.21       1.13
# 11       broky    NaN   144    3871       470  1.20       1.12
# 12       Spinx    NaN   140    3869       329  1.13       1.11
# 13     Twistzz    NaN   144    3871       227  1.09       1.10
# 14         NAF    NaN   129    3484       233  1.11       1.09
# ...

# %%
df=df.iloc[:, [0,2,3,4,5,6]]

# %%
df.head()
# Out:
#    Player  Maps  Rounds  K-D Diff   K/D  Rating2.0
# 1   ZywOo   140    3869       881  1.39       1.29
# 2   sh1ro   128    3540       801  1.41       1.23
# 3    NiKo   117    3106       368  1.19       1.20
# 4  m0NESY   117    3106       543  1.30       1.20
# 5  blameF   123    3432       432  1.21       1.19

# %%
df.Maps.mean()
# Out:
# 123.73469387755102

# %%
df.Rounds.mean()
# Out:
# 3362.326530612245

# %%
df.shape
# Out:
# (49, 6)

# %%
df1 = df[df["K-D Diff"]>0]

# %%
df1.shape
# Out:
# (27, 6)

# %%
df2 = df[df["K-D Diff"]<0]

# %%
df2.shape
# Out:
# (22, 6)

# %%
df.head()
# Out:
#    Player  Maps  Rounds  K-D Diff   K/D  Rating2.0
# 1   ZywOo   140    3869       881  1.39       1.29
# 2   sh1ro   128    3540       801  1.41       1.23
# 3    NiKo   117    3106       368  1.19       1.20
# 4  m0NESY   117    3106       543  1.30       1.20
# 5  blameF   123    3432       432  1.21       1.19

# %%
df["K/D"].mean()
# Out:
# 1.0216326530612243

# %%
df["Rating2.0"].mean()
# Out:
# 1.0479591836734694

# %%
df["New_Rating"] = df["Rating2.0"]*0.3+df["Maps"]*0.1+df["Rounds"]*0.1+df["K-D Diff"]*0.25+df["K/D"]*0.25

# %%
#df.drop("New", axis=1, inplace=True)

# %%
df.head()
# Out:
#    Player  Maps  Rounds  K-D Diff   K/D  Rating2.0  New_Rating
# 1   ZywOo   140    3869       881  1.39       1.29    621.8845
# 2   sh1ro   128    3540       801  1.41       1.23    567.7715
# 3    NiKo   117    3106       368  1.19       1.20    414.9575
# 4  m0NESY   117    3106       543  1.30       1.20    458.7350
# 5  blameF   123    3432       432  1.21       1.19    464.1595

# %%
df.sort_values(by="New_Rating", ascending=False).head()
# Out:
#    Player  Maps  Rounds  K-D Diff   K/D  Rating2.0  New_Rating
# 1   ZywOo   140    3869       881  1.39       1.29    621.8845
# 2   sh1ro   128    3540       801  1.41       1.23    567.7715
# 8    ropz   144    3871       482  1.20       1.14    522.6420
# 11  broky   144    3871       470  1.20       1.12    519.6360
# 12  Spinx   140    3869       329  1.13       1.11    483.7655

# %%
df.New_Rating=df.New_Rating.round(2)

# %%
df.head()
# Out:
#    Player  Maps  Rounds  K-D Diff   K/D  Rating2.0  New_Rating
# 1   ZywOo   140    3869       881  1.39       1.29      621.88
# 2   sh1ro   128    3540       801  1.41       1.23      567.77
# 3    NiKo   117    3106       368  1.19       1.20      414.96
# 4  m0NESY   117    3106       543  1.30       1.20      458.74
# 5  blameF   123    3432       432  1.21       1.19      464.16

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import seaborn as sns

# %%
plt.figure(figsize=(9,6))

sns.scatterplot(x="Maps", y="Rounds", data=df);
plt.show()

# %%
sns.displot(x= "Rating2.0", data=df, kde=True)
plt.show()

# %%
sns.histplot(data=df, x="New_Rating", bins=10)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax = df["Rating2.0"].sort_values(ascending=False)[:5].plot(kind='bar', ax=ax)
ax.set_xticklabels(df.sort_values(by="Rating2.0", ascending=False)["Player"][:5], rotation=45)

for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.25, p.get_height()), ha='center', va='top', color='yellow', size=18)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5))

df["New_Rating"].sort_values(ascending=False)[:5].plot(kind='bar', ax=ax)
ax.set_xticklabels(df.sort_values(by="New_Rating", ascending=False)["Player"][:5], rotation=45)


for p in ax.patches:
     ax.annotate(f'\n{p.get_height()+0.1}', (p.get_x()+0.02, p.get_height()), size=14)
plt.show()

# %%
df.New_Rating.mean()
# Out:
# 359.52265306122445

# %%
explode = (0, 0, 0.1, 0, 0, 0)

fig1, ax1 = plt.subplots(figsize=(10,10))

ax1.pie(x = df["Rating2.0"][:10], 
        labels=df.Player[:10], 
        labeldistance=0.8,
        autopct='%.1f%%',

#         shadow=True, 
        startangle=0,
#         radius=1.5,
       );

# %%
# with pandas
fig, ax = plt.subplots(figsize=(15,8))
df.sort_values(by="K-D Diff", ascending=False)["K-D Diff"][:10].plot(rot=45, kind='bar', ax=ax)

ax.set_ylabel("K/D Diff")
ax.set_xlabel("Player")
ax.set_title("Top 10 Players with highest K/D Difference")
ax.set_xticklabels(df.sort_values(by="K-D Diff", ascending=False)["Player"][:10], rotation=45)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.10, p.get_height()+0.5), size=15);

# %%
fig, ax = plt.subplots(figsize=(15,8))
df.sort_values(by="K/D", ascending=False)["K/D"][:10].plot(rot=45, kind='bar', ax=ax)

ax.set_ylabel("K/D Ratio")
ax.set_xlabel("Player")
ax.set_title("Top 10 Players with highest K/D Ratio")
ax.set_xticklabels(df.sort_values(by="K/D", ascending=False)["Player"][:10], rotation=45)

for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.25, p.get_height()), ha='center', va='top', color='yellow', size=18)
plt.show()

# %%
df.head()
# Out:
#    Player  Maps  Rounds  K-D Diff   K/D  Rating2.0  New_Rating
# 1   ZywOo   140    3869       881  1.39       1.29      621.88
# 2   sh1ro   128    3540       801  1.41       1.23      567.77
# 3    NiKo   117    3106       368  1.19       1.20      414.96
# 4  m0NESY   117    3106       543  1.30       1.20      458.74
# 5  blameF   123    3432       432  1.21       1.19      464.16

# %%
# with pandas
fig, ax = plt.subplots(figsize=(15,8))
df.sort_values(by="Rounds", ascending=False)["Rounds"][:10].plot(rot=45, kind='bar', ax=ax)

ax.set_ylabel("Rounds Ratio")
ax.set_xlabel("Player")
ax.set_title("Top 10 Players with most rounds played")
ax.set_xticklabels(df.sort_values(by="Rounds", ascending=False)["Player"][:10], rotation=45)

for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.25, p.get_height()), ha='center', va='top', color='yellow', size=18)
plt.show()

# %%
# with pandas
fig, ax = plt.subplots(figsize=(15,8))
df.sort_values(by="K/D")["K/D"][:10].plot(rot=45, kind='bar', ax=ax)

ax.set_ylabel("K/D Ratio")
ax.set_xlabel("Player")
ax.set_title("Worst Players with lowest K/D Ratio")
ax.set_xticklabels(df.sort_values(by="K/D")["Player"][:10], rotation=45)

for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.25, p.get_height()), ha='center', va='top', color='yellow', size=18)
plt.show()

# %%
# with pandas
fig, ax = plt.subplots(figsize=(15,8))
df.sort_values(by="K-D Diff")["K-D Diff"][:10].plot(rot=45, kind='bar', ax=ax)

ax.set_ylabel("K/D Ratio")
ax.set_xlabel("Player")
ax.set_title("Worst Players with lowest K/D Difference")
ax.set_xticklabels(df.sort_values(by="K-D Diff")["Player"][:10], rotation=45)

for p in ax.patches:
     ax.annotate(f'\n{p.get_height()-0.2}', (p.get_x()+0.25, p.get_height()-0.2), ha='center', va='top', size=18)
plt.show()

# %%
sns.boxplot(x=df["Rating2.0"].values)
plt.show()

# %%
sns.boxplot(df["Rating2.0"].values)
plt.show()

# %%
df[df["Rating2.0"]>1.2]
# Out:
#   Player  Maps  Rounds  K-D Diff   K/D  Rating2.0  New_Rating
# 1  ZywOo   140    3869       881  1.39       1.29      621.88
# 2  sh1ro   128    3540       801  1.41       1.23      567.77

# %%
df[df["New_Rating"]>500][:2]
# Out:
#   Player  Maps  Rounds  K-D Diff   K/D  Rating2.0  New_Rating
# 1  ZywOo   140    3869       881  1.39       1.29      621.88
# 2  sh1ro   128    3540       801  1.41       1.23      567.77

# %%
df.head()
# Out:
#    Player  Maps  Rounds  K-D Diff   K/D  Rating2.0  New_Rating
# 1   ZywOo   140    3869       881  1.39       1.29      621.88
# 2   sh1ro   128    3540       801  1.41       1.23      567.77
# 3    NiKo   117    3106       368  1.19       1.20      414.96
# 4  m0NESY   117    3106       543  1.30       1.20      458.74
# 5  blameF   123    3432       432  1.21       1.19      464.16

# %%
plt.figure(figsize=(9,6))

sns.scatterplot(x="Rating2.0", y="New_Rating", data=df);
plt.show()

# %%
df.to_excel("cs go top 50.xls")
# Out:
# C:\Users\44778\AppData\Local\Temp\ipykernel_10916\2177517777.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("cs go top 50.xls")
